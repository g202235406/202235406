# %%
from sklearn.datasets import load_wine
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
wine_data = load_wine()
df_data=pd.DataFrame(wine_data.data, columns=wine_data.feature_names)
df_target=pd.DataFrame(wine_data.target, columns=["kind"])
totall_data=pd.concat([df_data,df_target], axis=1)

# %%
totall_data.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline', 'kind'],
#       dtype='object')

# %%
df_data.isnull().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# dtype: int64

# %%
df_data.dropna() #결측값 있는 행 제거
df_data.dropna(axis=1) #결측값 있는 열 제거
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(x="color_intensity",data=totall_data, palette="Set3")
plt.title("Color Intensity")
plt.show()

# %%
sns.countplot(data=totall_data, x="kind")
# Out:
# <AxesSubplot:xlabel='kind', ylabel='count'>

# %%
totall_data
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline  kind
# 0                            3.92   1065.0     0
# 1                            3.40   1050.0     0
# 2                            3.17   1185.0     0
# 3                            3.45   1480.0     0
# 4                            2.93    735.0     0
# ..                            ...      ...   ...
# 173                          1.74    740.0     2
# 174                          1.56    750.0     2
# 175                          1.56    835.0     2
# 176                          1.62    840.0     2
# 177                          1.60    560.0     2
#
# [178 rows x 14 columns]

# %%
sns.pairplot(totall_data,
             vars=['color_intensity', 'hue'],
            hue ='kind')
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(x="kind", y="color_intensity", data=totall_data)
plt.title("Color Intensity")
plt.show()

# %%
sns.boxplot(x="kind", y="alcohol", data=totall_data)
plt.title("Alcohol")
# Out:
# Text(0.5, 1.0, 'Alcohol')

# %%
#X=totall_data.drop('kind',axis=1)
#X.head()

# %%
y=totall_data['kind']
y.value_counts()
# Out:
# 1    71
# 0    59
# 2    48
# Name: kind, dtype: int64

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Name: kind, Length: 178, dtype: int32

# %%
#Splitting the data into training and test test
X = totall_data.iloc[:,0:13].values
y = totall_data.iloc[:,13:].values

from sklearn.preprocessing import LabelEncoder
encoder =  LabelEncoder()
y1 = encoder.fit_transform(y)

Y = pd.get_dummies(y1).values

from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
X
# Out:
# array([[1.423e+01, 1.710e+00, 2.430e+00, ..., 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.320e+01, 1.780e+00, 2.140e+00, ..., 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.316e+01, 2.360e+00, 2.670e+00, ..., 1.030e+00, 3.170e+00,
#         1.185e+03],
#        ...,
#        [1.327e+01, 4.280e+00, 2.260e+00, ..., 5.900e-01, 1.560e+00,
#         8.350e+02],
#        [1.317e+01, 2.590e+00, 2.370e+00, ..., 6.000e-01, 1.620e+00,
#         8.400e+02],
#        [1.413e+01, 4.100e+00, 2.740e+00, ..., 6.100e-01, 1.600e+00,
#         5.600e+02]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD,Adam
from keras.layers import Input, Dense
from keras.models import Model

# 이는 텐서를 반환합니다
inputs = Input(shape=(13,))
x = Dense(15, activation='relu')(inputs)
x1 = Dense(8, activation='relu')(x)
x2 = Dense(6, activation='relu')(x1)
outputs=Dense(3,activation='softmax')(x2)

model = Model(inputs=inputs, outputs=outputs)
model.compile(Adam(lr=0.04), 'categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 13)]              0
#
#  dense (Dense)               (None, 15)                210
#
#  dense_1 (Dense)             (None, 8)                 128
#
#  dense_2 (Dense)             (None, 6)                 54
#
#  dense_3 (Dense)             (None, 3)                 21
#
# =================================================================
# Total params: 413
# Trainable params: 413
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=100, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 38ms/step - loss: 19.8928 - accuracy: 0.3873 - val_loss: 15.1489 - val_accuracy: 0.4444
# Epoch 2/100
# 5/5 [==============================] - 0s 7ms/step - loss: 13.2673 - accuracy: 0.3873 - val_loss: 12.1380 - val_accuracy: 0.4444
# Epoch 3/100
# 5/5 [==============================] - 0s 6ms/step - loss: 10.9743 - accuracy: 0.3873 - val_loss: 9.8978 - val_accuracy: 0.4167
# Epoch 4/100
# 5/5 [==============================] - 0s 5ms/step - loss: 8.7907 - accuracy: 0.3521 - val_loss: 7.7677 - val_accuracy: 0.3333
# Epoch 5/100
# 5/5 [==============================] - 0s 6ms/step - loss: 6.
# Epoch 71/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8227 - accuracy: 0.5211 - val_loss: 0.7468 - val_accuracy: 0.5278
# Epoch 72/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8198 - accuracy: 0.5423 - val_loss: 0.7687 - val_accuracy: 0.5278
# Epoch 73/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8118 - accuracy: 0.5423 - val_loss: 0.7564 - val_accuracy: 0.5000
# Epoch 74/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8096 - accuracy: 0.5493 - val_loss: 0.7475 - val_accuracy: 0.5000
# Epoch 75/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8077 - accuracy: 0.5423 - val_loss: 0.7484 - val_accuracy: 0.5000
# Epoch 76/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8070 - accuracy: 0.5423 - val_loss: 0.7438 - val_accuracy: 0.5000
# Epoch 77/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8055 - accuracy: 0.5423 - val_loss: 0.7433 - val_accuracy: 0.5000
# Epoch 78/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8043 - accuracy: 0.5493 - val_loss: 0.7484 - val_accuracy: 0.5278
# Epoch 79/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8016 - accuracy: 0.5563 - val_loss: 0.7367 - val_accuracy: 0.5000
# Epoch 80/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8029 - accuracy: 0.5423 - val_loss: 0.7333 - val_accuracy: 0.5278
# Epoch 81/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8034 - accuracy: 0.5493 - val_loss: 0.7316 - val_accuracy: 0.5278
# Epoch 82/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8037 - accuracy: 0.5352 - val_loss: 0.7319 - val_accuracy: 0.5278
# Epoch 83/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.8004 - accuracy: 0.5493 - val_loss: 0.7343 - val_accuracy: 0.5000
# Epoch 84/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7971 - accuracy: 0.5423 - val_loss: 0.7482 - val_accuracy: 0.5278
# Epoch 85/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8009 - accuracy: 0.5634 - val_loss: 0.7556 - val_accuracy: 0.5278
# Epoch 86/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7953 - accuracy: 0.5563 - val_loss: 0.7285 - val_accuracy: 0.5000
# Epoch 87/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8014 - accuracy: 0.5352 - val_loss: 0.7238 - val_accuracy: 0.5278
# Epoch 88/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7956 - accuracy: 0.5563 - val_loss: 0.7466 - val_accuracy: 0.5278
# Epoch 89/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7944 - accuracy: 0.5563 - val_loss: 0.7412 - val_accuracy: 0.5278
# Epoch 90/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7933 - accuracy: 0.5563 - val_loss: 0.7370 - val_accuracy: 0.5278
# Epoch 91/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7883 - accuracy: 0.5563 - val_loss: 0.7180 - val_accuracy: 0.5278
# Epoch 92/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7973 - accuracy: 0.5352 - val_loss: 0.7166 - val_accuracy: 0.5278
# Epoch 93/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7876 - accuracy: 0.5563 - val_loss: 0.7580 - val_accuracy: 0.4722
# Epoch 94/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7935 - accuracy: 0.5634 - val_loss: 0.7420 - val_accuracy: 0.5278
# Epoch 95/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7896 - accuracy: 0.5563 - val_loss: 0.7152 - val_accuracy: 0.7500
# Epoch 96/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7895 - accuracy: 0.6056 - val_loss: 0.7138 - val_accuracy: 0.7500
# Epoch 97/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7826 - accuracy: 0.6056 - val_loss: 0.7227 - val_accuracy: 0.8056
# Epoch 98/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7939 - accuracy: 0.6197 - val_loss: 0.7655 - val_accuracy: 0.7500
# Epoch 99/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7895 - accuracy: 0.6268 - val_loss: 0.7251 - val_accuracy: 0.7778
# Epoch 100/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7800 - accuracy: 0.6056 - val_loss: 0.7072 - val_accuracy: 0.7500
# 2/2 [==============================] - 0s 1ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87        14
#            1       0.70      0.88      0.78        16
#            2       0.00      0.00      0.00         6
#
#     accuracy                           0.75        36
#    macro avg       0.50      0.60      0.55        36
# weighted avg       0.63      0.75      0.68        36
#
# [[13  1  0]
#  [ 2 14  0]
#  [ 1  5  0]]
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
